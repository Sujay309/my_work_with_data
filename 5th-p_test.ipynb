# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[0:100]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
#implicit indexing
df.iloc[0:2] #stert  from 0 and go to till 1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.loc[0:2] # loc is used for named indexes, iloc is used for interger indexing
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.loc[0:2, ['Name','Parch']]
# Out:
#                                                 Name  Parch
# 0                            Braund, Mr. Owen Harris      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0
# 2                             Heikkinen, Miss. Laina      0

# %%
df.iloc[0:2, 3:6]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0

# %%
df['Name'][2:5]
# Out:
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
list(df['Name'][2:5])
# Out:
# ['Heikkinen, Miss. Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry']

# %%
s= pd.Series(list(df['Name'][2:5]), index=['a','b','c'])

# %%
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s1=pd.Series(list(df['Name'][5:8]))

# %%
s1
# Out:
# 0                  Moran, Mr. James
# 1           McCarthy, Mr. Timothy J
# 2    Palsson, Master. Gosta Leonard
# dtype: object

# %%
s1=pd.Series(list(df['Name'][5:8]), index=['a','b','c'])

# %%
#series and dataframe cannot be concatenated
#if you keep the index same, then for series concatenation can happen
s1
# Out:
# a                  Moran, Mr. James
# b           McCarthy, Mr. Timothy J
# c    Palsson, Master. Gosta Leonard
# dtype: object

# %%
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s+s1
# Out:
# a               Heikkinen, Miss. LainaMoran, Mr. James
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)Mc...
# c    Allen, Mr. William HenryPalsson, Master. Gosta...
# dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#drop a column
df.drop('PassengerId', axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 151         1       1                  Pears, Mrs. Thomas (Edith Wearne)
# 152         0       3                                   Meo, Mr. Alfonzo
# 153         0       3                    van Billiard, Mr. Austin Blyler
# 154         0       3                              Olsen, Mr. Ole Martin
# 155         0       1                        Williams, Mr. Charles Duane
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop('PassengerId', axis=1, inplace= True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 151         1       1                  Pears, Mrs. Thomas (Edith Wearne)
# 152         0       3                                   Meo, Mr. Alfonzo
# 153         0       3                    van Billiard, Mr. Austin Blyler
# 154         0       3                              Olsen, Mr. Ole Martin
# 155         0       1                        Williams, Mr. Charles Duane
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(1, inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 151         1       1             Pears, Mrs. Thomas (Edith Wearne)  female
# 152         0       3                              Meo, Mr. Alfonzo    male
# 153         0       3               van Billiard, Mr. Austin Blyler    male
# 154         0       3                         Olsen, Mr. Ole Martin    male
# 155         0       1                   Williams, Mr. Charles Duane    male
#
# ...

# %%
df.reset_index(drop = True)
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 1           1       3                        Heikkinen, Miss. Laina  female
# 2           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3           0       3                      Allen, Mr. William Henry    male
# 4           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 150         1       1             Pears, Mrs. Thomas (Edith Wearne)  female
# 151         0       3                              Meo, Mr. Alfonzo    male
# 152         0       3               van Billiard, Mr. Austin Blyler    male
# 153         0       3                         Olsen, Mr. Ole Martin    male
# 154         0       1                   Williams, Mr. Charles Duane    male
#
# ...

# %%
df.set_index('Name', inplace=True)

# %%
df
# Out:
#                                               Survived  Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                              0       3    male  22.0
# Heikkinen, Miss. Laina                               1       3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female  35.0
# Allen, Mr. William Henry                             0       3    male  35.0
# Moran, Mr. James                                     0       3    male   NaN
# ...                                                ...     ...     ...   ...
# Pears, Mrs. Thomas (Edith Wearne)                    1       1  female  22.0
# Meo, Mr. Alfonzo                                     0       3    male  55.5
# van Billiard, Mr. Austin Blyler                      0       3    male  40.5
# Olsen, Mr. Ole Martin                                0       3    male   NaN
# Williams, Mr. Charles Duane                          0       1    male  51.0
#
# ...

# %%
df.loc['Braund, Mr. Owen Harris']
# Out:
# Survived            0
# Pclass              3
# Sex              male
# Age              22.0
# SibSp               1
# Parch               0
# Ticket      A/5 21171
# Fare             7.25
# Cabin             NaN
# Embarked            S
# Name: Braund, Mr. Owen Harris, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                              Name  Survived  Pclass     Sex  \
# 0                         Braund, Mr. Owen Harris         0       3    male
# 1                          Heikkinen, Miss. Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                        Allen, Mr. William Henry         0       3    male
# 4                                Moran, Mr. James         0       3    male
# ..                                            ...       ...     ...     ...
# 150             Pears, Mrs. Thomas (Edith Wearne)         1       1  female
# 151                              Meo, Mr. Alfonzo         0       3    male
# 152               van Billiard, Mr. Austin Blyler         0       3    male
# 153                         Olsen, Mr. Ole Martin         0       3    male
# 154                   Williams, Mr. Charles Duane         0       1    male
#
# ...

# %%
d ={'key1':[1,2,3,4],
    'key2': [5,6,7,8],
    'key3': [2,3,7,8]}

# %%
d
# Out:
# {'key1': [1, 2, 3, 4], 'key2': [5, 6, 7, 8], 'key3': [2, 3, 7, 8]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     5     2
# 1     2     6     3
# 2     3     7     7
# 3     4     8     8

# %%
d ={'key1':(1,2,3,4),
    'key2': (5,6,7,8),
    'key3': (2,3,7,8)}

# %%
d
# Out:
# {'key1': (1, 2, 3, 4), 'key2': (5, 6, 7, 8), 'key3': (2, 3, 7, 8)}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     5     2
# 1     2     6     3
# 2     3     7     7
# 3     4     8     8

# %%
df1 = pd.read_csv("taxonomy.csv")

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.shape
# Out:
# (290, 4)

# %%
df1.describe()
# Out:
#        taxonomy_id          name  parent_id       parent_name
# count          290           290        279               279
# unique         290           183         60                50
# top            101  Nursing Home  106-06-07  Health Education
# freq             1             4         11                15

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   taxonomy_id  290 non-null    object
#  1   name         290 non-null    object
#  2   parent_id    279 non-null    object
#  3   parent_name  279 non-null    object
# dtypes: object(4)
# memory usage: 9.2+ KB

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.isnull().sum()
# Out:
# taxonomy_id     0
# name            0
# parent_id      11
# parent_name    11
# dtype: int64

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna() # remove null values row wise
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis = 1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df1[['name']].dropna(axis=1) # for one column
# Out:
#                              name
# 0                       Emergency
# 1               Disaster Response
# 2                  Emergency Cash
# 3               Help Pay for Food
# 4         Help Pay for Healthcare
# ..                            ...
# 285              Workplace Rights
# 286                     Mediation
# 287                        Notary
# 288                Representation
# 289  Translation & Interpretation
#
# [290 rows x 1 columns]

# %%
#imputation of missing valu 
# numaric data>> mean and median>> outliar treatment done>> mean else median
# catagorical>> mode
# impute misssing valu may be with some constent >> 0

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.fillna("0")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency         0                     0
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.fillna("somevalu")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency  somevalu              somevalu
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.parent_id
# Out:
# 0         NaN
# 1         101
# 2         101
# 3      101-02
# 4      101-02
#         ...
# 285    111-01
# 286       111
# 287       111
# 288       111
# 289       111
# Name: parent_id, Length: 290, dtype: object

# %%
data1 = {
    'A' : [1, 2, None, 4, 5, None, 7, 8, 9, 10],
    'B' : [None, 11, 12, 13, None, 15, 16, None, 18, 19]
}

df2 = pd.DataFrame(data1)
df2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.A
# Out:
# 0     1.0
# 1     2.0
# 2     NaN
# 3     4.0
# 4     5.0
# 5     NaN
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# Name: A, dtype: float64

# %%
df2.A.fillna(df2['A'].mean())
# Out:
# 0     1.00
# 1     2.00
# 2     5.75
# 3     4.00
# 4     5.00
# 5     5.75
# 6     7.00
# 7     8.00
# 8     9.00
# 9    10.00
# Name: A, dtype: float64

# %%
df2.A.fillna(df2['A'].median())
# Out:
# 0     1.0
# 1     2.0
# 2     6.0
# 3     4.0
# 4     5.0
# 5     6.0
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# Name: A, dtype: float64

# %%
df2.A.fillna(df2['A'].mode())
# Out:
# 0     1.0
# 1     2.0
# 2     4.0
# 3     4.0
# 4     5.0
# 5     8.0
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# Name: A, dtype: float64

# %%
df2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.fillna(0)
# Out:
#       A     B
# 0   1.0   0.0
# 1   2.0  11.0
# 2   0.0  12.0
# 3   4.0  13.0
# 4   5.0   0.0
# 5   0.0  15.0
# 6   7.0  16.0
# 7   8.0   0.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.fillna('something')
# Out:
#            A          B
# 0        1.0  something
# 1        2.0       11.0
# 2  something       12.0
# 3        4.0       13.0
# 4        5.0  something
# 5  something       15.0
# 6        7.0       16.0
# 7        8.0  something
# 8        9.0       18.0
# 9       10.0       19.0

# %%
df2.fillna(method='ffill') #forword fill >> start seeing from the bottom of dataframe and fill with the next value observed
# Out:
# C:\Users\sujay\AppData\Local\Temp\ipykernel_18996\1047838960.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2.fillna(method='ffill') #forword fill >> start seeing from the bottom of dataframe and fill with the next value observed
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   2.0  12.0
# 3   4.0  13.0
# 4   5.0  13.0
# 5   5.0  15.0
# 6   7.0  16.0
# 7   8.0  16.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.fillna(method='bfill') # backword fill >> see from top and fill with next observed value
# Out:
# C:\Users\sujay\AppData\Local\Temp\ipykernel_18996\1548114720.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2.fillna(method='bfill') # backword fill >> see from top and fill with next observed value
#       A     B
# 0   1.0  11.0
# 1   2.0  11.0
# 2   4.0  12.0
# 3   4.0  13.0
# 4   5.0  15.0
# 5   7.0  15.0
# 6   7.0  16.0
# 7   8.0  18.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#                                              Name  Survived  Pclass     Sex  \
# 0                         Braund, Mr. Owen Harris         0       3    male
# 1                          Heikkinen, Miss. Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                        Allen, Mr. William Henry         0       3    male
# 4                                Moran, Mr. James         0       3    male
# ..                                            ...       ...     ...     ...
# 150             Pears, Mrs. Thomas (Edith Wearne)         1       1  female
# 151                              Meo, Mr. Alfonzo         0       3    male
# 152               van Billiard, Mr. Austin Blyler         0       3    male
# 153                         Olsen, Mr. Ole Martin         0       3    male
# 154                   Williams, Mr. Charles Duane         0       1    male
#
# ...

# %%
df2.mean()
# Out:
# A     5.750000
# B    14.857143
# dtype: float64

# %%
df2.median()
# Out:
# A     6.0
# B    15.0
# dtype: float64

# %%
df2.std()
# Out:
# A    3.284161
# B    3.023716
# dtype: float64

# %%
df.Age.describe()
# Out:
# count    125.000000
# mean      28.062640
# std       14.645741
# min        0.830000
# 25%       19.000000
# 50%       26.000000
# 75%       35.000000
# max       71.000000
# Name: Age, dtype: float64

# %%
df
# Out:
#                                              Name  Survived  Pclass     Sex  \
# 0                         Braund, Mr. Owen Harris         0       3    male
# 1                          Heikkinen, Miss. Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                        Allen, Mr. William Henry         0       3    male
# 4                                Moran, Mr. James         0       3    male
# ..                                            ...       ...     ...     ...
# 150             Pears, Mrs. Thomas (Edith Wearne)         1       1  female
# 151                              Meo, Mr. Alfonzo         0       3    male
# 152               van Billiard, Mr. Austin Blyler         0       3    male
# 153                         Olsen, Mr. Ole Martin         0       3    male
# 154                   Williams, Mr. Charles Duane         0       1    male
#
# ...

# %%
#Q. what is the avarage fere paid by people who survived ?

# %%
# avarage fare survived
df[df.Survived == 1]['Fare'].mean()
# Out:
# 28.908726415094343

# %%
# avg fare how didnt survived 
df[df.Survived == 0]['Fare'].mean()
# Out:
# 27.271076470588238

# %%
# groupby

# %%
df.groupby('Survived').mean(numeric_only=True)
# Out:
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.490196  29.358824  0.666667  0.372549  27.271076
# 1         2.320755  25.308250  0.509434  0.452830  28.908726

# %%
df.groupby('Survived').min(numeric_only=True)
# Out:
#           Pclass   Age  SibSp  Parch    Fare
# Survived
# 0              1  2.00      0      0  6.7500
# 1              1  0.83      0      0  7.1417

# %%
df.groupby('Survived').sum(numeric_only=True)
# Out:
#           Pclass      Age  SibSp  Parch       Fare
# Survived
# 0            254  2495.50     68     38  2781.6498
# 1            123  1012.33     27     24  1532.1625

# %%
df.groupby('Survived').describe()
# Out:
#          Pclass                                                Age             \
#           count      mean       std  min  25%  50%  75%  max count       mean
# Survived
# 0         102.0  2.490196  0.780265  1.0  2.0  3.0  3.0  3.0  85.0  29.358824
# 1          53.0  2.320755  0.803205  1.0  2.0  3.0  3.0  3.0  40.0  25.308250
#
#           ... Parch        Fare                                                \
#           ...   75%  max  count       mean        std     min    25%      50%
# Survived  ...
# 0         ...   0.0  5.0  102.0  27.271076  38.516545  6.7500  8.050  13.7271
# 1         ...   0.0  5.0   53.0  28.908726  41.329610  7.1417  7.925  15.2458
#
#
#                75%    max
# Survived
# 0         30.97395  263.0
# 1         29.00000  263.0
#
# [2 rows x 40 columns]

# %%
import numpy as np
df.groupby(['Survived'])['Fare'].agg([min, 'max', 'mean','median', 'count', np.std, 'var'])
# Out:
# C:\Users\sujay\AppData\Local\Temp\ipykernel_18996\32886713.py:2: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby(['Survived'])['Fare'].agg([min, 'max', 'mean','median', 'count', np.std, 'var'])
# C:\Users\sujay\AppData\Local\Temp\ipykernel_18996\32886713.py:2: FutureWarning: The provided callable <function std at 0x000001FA000D40E0> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   df.groupby(['Survived'])['Fare'].agg([min, 'max', 'mean','median', 'count', np.std, 'var'])
#              min    max       mean   median  count        std          var
# Survived
# 0         6.7500  263.0  27.271076  13.7271    102  38.516545  1483.524225
# ...

# %%
df[['Survived', 'Fare']]
# Out:
#      Survived     Fare
# 0           0   7.2500
# 1           1   7.9250
# 2           1  53.1000
# 3           0   8.0500
# 4           0   8.4583
# ..        ...      ...
# 150         1  66.6000
# 151         0   8.0500
# 152         0  14.5000
# 153         0   7.3125
# 154         0  61.3792
#
# [155 rows x 2 columns]

# %%
df.groupby(['Sex','Pclass'])['Survived'].sum()
# Out:
# Sex     Pclass
# female  1          8
#         2         11
#         3         20
# male    1          3
#         2          3
#         3          8
# Name: Survived, dtype: int64

# %%
df.groupby(['Sex','Pclass'])['Survived'].sum().to_frame()
# Out:
#                Survived
# Sex    Pclass
# female 1              8
#        2             11
#        3             20
# male   1              3
#        2              3
#        3              8

# %%
df.groupby(['Sex','Pclass'])['Survived'].sum().unstack()
# Out:
# Pclass  1   2   3
# Sex
# female  8  11  20
# male    3   3   8

# %%
df.groupby('Pclass').sum(numeric_only=True)
# Out:
#         Survived      Age  SibSp  Parch       Fare
# Pclass
# 1             11   991.00     15     12  2313.7749
# 2             14   815.33     12     10   709.7916
# 3             28  1701.50     68     40  1290.2458

# %%
a = df.groupby('Pclass').sum(numeric_only=True)

# %%
a
# Out:
#         Survived      Age  SibSp  Parch       Fare
# Pclass
# 1             11   991.00     15     12  2313.7749
# 2             14   815.33     12     10   709.7916
# 3             28  1701.50     68     40  1290.2458

# %%
a.T
# Out:
# Pclass            1         2          3
# Survived    11.0000   14.0000    28.0000
# Age        991.0000  815.3300  1701.5000
# SibSp       15.0000   12.0000    68.0000
# Parch       12.0000   10.0000    40.0000
# Fare      2313.7749  709.7916  1290.2458

# %%
a.transpose()
# Out:
# Pclass            1         2          3
# Survived    11.0000   14.0000    28.0000
# Age        991.0000  815.3300  1701.5000
# SibSp       15.0000   12.0000    68.0000
# Parch       12.0000   10.0000    40.0000
# Fare      2313.7749  709.7916  1290.2458

# %%
df.head().T
# Out:
#                                 0                       1  \
# Name      Braund, Mr. Owen Harris  Heikkinen, Miss. Laina
# Survived                        0                       1
# Pclass                          3                       3
# Sex                          male                  female
# Age                          22.0                    26.0
# SibSp                           1                       0
# Parch                           0                       0
# Ticket                  A/5 21171        STON/O2. 3101282
# Fare                         7.25                   7.925
# Cabin                         NaN                     NaN
# Embarked                        S                       S
#
#                                                      2  \
# Name      Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Survived                                             1
# Pclass                                               1
# ...
