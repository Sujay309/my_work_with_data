# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import statistics as st
import math as m

# %%
data = [1,2,3,4,5]
data
# Out:
# [1, 2, 3, 4, 5]

# %%
np.mean(data)
# Out:
# 3.0

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
np.mean(df['tip'])
# Out:
# 2.99827868852459

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
np.median(data)
# Out:
# 3.0

# %%
np.median(df['tip'])
# Out:
# 2.9

# %%
# mean is inflated by the outlier whereas median is not inflated

# %%
data = [1,2,3,4,5,500]

# %%
np.mean(data)
# Out:
# 85.83333333333333

# %%
np.median(data)
# Out:
# 3.5

# %%
data = [1,2,1,100,100,100,3,4,78]  # numpy not saport mode function

st.mode(data) #st for statistics
# Out:
# 100

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
data
# Out:
# [1, 2, 1, 100, 100, 100, 3, 4, 78]

# %%
np.percentile(data, [25])
# Out:
# array([2.])

# %%
np.percentile(data, [25, 50, 75, 100])
# Out:
# array([  2.,   4., 100., 100.])

# %%
data.append(-800)
data.append(600)

# %%
data
# Out:
# [1, 2, 1, 100, 100, 100, 3, 4, 78, -800, 600]

# %%
sns.boxenplot(data)
# Out:
# <Axes: >

# %%
np.var(data)
# Out:
# 93897.05785123968

# %%
np.std(data)
# Out:
# 306.42626821348017

# %%
np.mean(data)
# Out:
# 17.181818181818183

# %%
st.variance(data) #sample variance
# Out:
# 103286.76363636364

# %%
st.pvariance(data) #population variance
# Out:
# 93897.05785123968

# %%
#standard devisution using math libary
m.sqrt(st.pvariance(data))
# Out:
# 306.42626821348017

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1 = df [['total_bill','tip', 'size']]

# %%
corr = df1.corr()  #  corellation

# %%
sns.heatmap(corr, annot= True)
# Out:
# <Axes: >

# %%
df1.cov()   # covarrence
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %%
sns.pairplot(df1)

# %%
sns.histplot(data)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(df['total_bill'], kde= True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(df['total_bill'], kde= True)

# %%
# generate normal distribution data using numpy

np.random.normal(0.5, 0.2, 1000)
# Out:
# array([ 0.30145723,  0.75321951,  0.28098711,  0.4688471 ,  0.7838526 ,
#         0.55081215,  0.64958101,  0.34334537,  0.65475377,  0.7580179 ,
#         0.58319392,  0.14613788,  0.42588549,  0.87239679,  0.64409864,
#         0.48151948,  0.52413731,  0.40841692,  0.45178187,  0.57048631,
#         0.79219646,  0.48514869,  0.52317656,  0.74890465,  0.24214514,
#         0.66310179,  0.64187184,  0.55946377,  0.40649583,  0.4895112 ,
#         0.33970834,  0.13205861,  0.73407879,  0.83964032,  0.26660548,
#         0.00656033,  0.86879818,  0.85408191,  0.51616677,  0.58070024,
#         0.49990905,  0.34580984,  0.77146388,  0.58039942,  0.9062506 ,
#         0.29585537,  0.16171173,  0.36891096,  0.1610131 ,  0.29789794,
#         0.33650262,  0.61249544,  0.37703746,  0.64744311,  0.56978331,
#         0.29949022,  0.71233442,  0.49815899,  0.19908295, -0.07878878,
#         0.78671038,  0.14113873,  0.68388888,  0.4997505 ,  0.50023687,
# ...

# %%
var = np.random.normal(0.5, 0.2, 1000)

# %%
sns.histplot(var, kde= True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.displot(var, kde= True)
